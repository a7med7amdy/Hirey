# %%
import pandas as pd
import csv 
import time
import os
from IPython.display import clear_output

# %%
df= pd.read_csv("DL_nour.csv")
df

# %%
ans=[]
kk=0
filename = "newfile.csv"    
with open(filename, 'w') as csvfile:  
    csvwriter = csv.writer(csvfile)  
    csvwriter.writerow(['Questions', 'ans1', 'ans2', 'class'])  
    prev_que = 'What is deep learning?'
    leng_que = 0     
    for index, row in df.iterrows():
        print(row[0])
        if row[0] == prev_que:
            leng_que += 1
            prev_que = row[0]
        else:
            print("Question" , prev_que)
            print("length", leng_que)
            print("-----------------------------------------")
            leng_que = 0    
        # if kk==0:
        #     print("entered kk = ",index)
        #     ans.append(row[1])
        #     kk=1
        # ans.append(row[2])
        # if index+1<len(df) and df["Questions"][index]!=df["Questions"][index+1]:
        #     kk=0
        #     for j in range(len(ans)):
        #         for k in range(j+1,len(ans)):
        #             rows=[row[0],ans[j],ans[k]]
        #             csvwriter.writerow(rows)
        #     ans=[]
        # elif index+1>=len(df):
        #     for j in range(len(ans)):
        #         for k in range(j+1,len(ans)):
        #             rows=[row[0],ans[j],ans[k]]
        #             csvwriter.writerow(rows)

# %%
df2= pd.read_csv("newfile.csv")

# %%
df2

# %%
##################################################
data= pd.read_csv("software_Ahmed.csv")
filename = "All_Software.csv"    
with open(filename, 'w', newline='') as csvfile:  
    csvwriter = csv.writer(csvfile)  
    csvwriter.writerow(['Questions', 'ans1', 'ans2', 'class'])  
    i = 1
    for index, row in data.iterrows():
        csvwriter.writerow(row)
        for index2, row2 in data.loc[index:].iterrows():
            if row[0] != row2[0]:
                csvwriter.writerow([row[0], row[i], row2[i], 0]) 
                if i == 1: 
                    i = 2
                else:
                    i = 1
                print("Question" , row[0])
                print(row[0], row[1], row2[1], 0)
                print("-----------------------------------------")
                break
# Out:
# Question What is the main difference between a computer program and computer software?
# What is the main difference between a computer program and computer software? PROGRAMS-A computer program is a collection of instructions that performs a specific task when executed by a computer. A set of instruction telling a computer what to do(instruction is in the form code .binary.) while SOFTWARE-Software are made up of two or more than two programs.
# It instruct computer processor to perform specific operation .
# (In simple words it give instruction or data to computer processor(CPU)) Software ReEngineering is the examination and alteration of a system to reconstitute it in a new form. The principles of Re-Engineering when applied to the software development process  0
# -----------------------------------------
# Question What is the main difference between a computer program and computer software?
# ...

# %%
import random
##################################################
data= pd.read_csv("newfileOOP.csv", encoding='latin1')
# data= pd.read_excel("NLP_Ayat.xlsx")
# data= pd.read_csv("DL_nour.csv", encoding='latin1')

filename = "All_OOP.csv"    
with open(filename, 'w', encoding="utf-8-sig", newline='') as csvfile:  
    csvwriter = csv.writer(csvfile)  
    csvwriter.writerow(['Questions', 'ans1', 'ans2', 'class'])  
    
    for index, row in data.iterrows():
        csvwriter.writerow(row)
        num = random.randint(0, 986)
        print(num)
        for index2, row2 in data.loc[num:].iterrows():
            if row[0] != row2[0]:
                csvwriter.writerow([row[0],  row[1], row2[1], 0]) 
                csvwriter.writerow([row2[0], row[2], row2[2], 0])
#                 print("Question" , row[0])
#                 print(row[0], row[1], row2[1], 0)
#                 print("-----------------------------------------")
                break
# Out:
# 232
# 93
# 470
# 180
# 613
# 470
# 758
# 280
# 620
# 795
# 473
# 250
# 929
# 543
# 288
# 517
# 902
# 411
# 749
# 511
# 611
# 401
# 718
# 409
# 306
# 325
# 651
# 361
# 372
# 730
# 291
# 50
# 369
# 270
# 755
# 169
# 688
# 978
# 312
# 675
# 140
# 779
# 601
# 592
# 414
# 181
# 81
# 269
# 104
# 506
# 378
# 457
# 760
# 948
# 552
# 542
# 398
# 386
# 864
# 650
# 677
# 350
# 32
# 639
# 892
# 34
# 481
# 98
# 108
# 135
# 820
# 134
# 474
# 198
# 265
# 816
# 843
# 240
# 936
# 449
# 908
# 10
# 401
# 762
# 777
# 428
# 406
# 139
# 574
# 952
# 135
# 148
# 689
# 627
# 932
# 644
# 466
# 154
# 933
# 676
# 39
# 815
# 840
# 937
# 522
# 398
# 23
# 980
# 828
# 87
# 364
# 310
# 221
# 433
# 693
# 419
# 228
# 358
# 363
# 411
# 92
# 188
# 129
# 32
# 281
# 187
# 679
# 838
# 206
# 201
# 364
# 438
# 495
# 69
# 849
# 305
# 239
# 528
# 50
# 885
# 142
# 610
# 603
# 865
# 369
# 873
# 232
# 12
# 414
# 607
# 188
# 560
# 847
# 19
# 781
# 526
# 644
# 704
# 129
# 670
# 709
# 499
# 520
# 201
# 645
# 949
# 881
# 675
# 626
# ...
